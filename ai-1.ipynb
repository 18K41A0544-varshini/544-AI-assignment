# %%
import pandas as pd
import numpy as np
import matplotlib as mtp
ds=pd.read_csv("mobile_cleaned-1549119762886_-452616671.csv")

# %%
ds=pd.read_csv("mobile_cleaned-1549119762886_-452616671.csv")
ds
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0           0        12        55   155.0          250.0                  1.3
# 1           0         1        55   132.0          300.0                  1.3
# 2           0         9        55   142.0          329.0                  1.5
# 3           0         8        55   152.0          385.0                  1.3
# 4           1         1        55   234.0          385.0                  1.3
# ..        ...       ...       ...     ...            ...                  ...
# 104         3        10        14   192.0          540.0                  1.8
# 105         0         5         3   157.0          400.0                  2.3
# 106         3        10         6   192.0          384.0                  1.8
# 107         3        10        12   129.0          250.0                  1.4
# 108         2         8         3   158.0          400.0                  2.2
#
#      thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0         10.5           5                     2.00           0  ...
# 1         10.6           5                     0.30           1  ...
# 2          8.5           5                     2.00           3  ...
# 3          8.0           5                     2.00           3  ...
# 4          7.9           5                     1.92           3  ...
# ..         ...         ...                      ...         ...  ...
# 104        9.4           2                     2.00           2  ...
# 105        7.7           5                     5.00           3  ...
# 106        7.3           2                     5.00           3  ...
# 107        6.9           2                     1.20           3  ...
# 108        7.4           6                     8.00           3  ...
#
#      micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# 0                4                     2                 3         67.8
# 1                4                     4                 6         64.0
# 2                4                     9                 6         72.0
# 3                4                     1                 3         75.1
# 4                4                     1                 6         91.0
# ..             ...                   ...               ...          ...
# 104              4                    29                 6         77.2
# 105              6                    27                 1         72.6
# 106              1                    16                 6         77.9
# 107              1                    13                 6         67.0
# 108              5                    16                 6         74.7
#
#      expandable_memory  version  usb_type  battery_capacity  processor_rank  \
# 0                   64        5         3              2000             125
# 1                   32        5         3              2000             165
# 2                   32        6         3              2500             164
# 3                   32        6         3              3000             165
# 4                   32        6         3              3000             165
# ..                 ...      ...       ...               ...             ...
# 104                256        6         3              3410               8
# 105                200        9         3              3600             101
# 106                  0       14        13              2750               1
# 107                  0       12        13              1810               7
# 108                  0       10        12              3000               2
#
#      is_liked
# 0           1
# 1           1
# 2           0
# 3           1
# 4           0
# ..        ...
# 104         1
# 105         1
# 106         1
# 107         1
# 108         0
#
# [109 rows x 40 columns]

# %%
ds.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               1
# stand_by_time                        3
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    2
# os                                   0
# phone_height                         1
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            1
# video_resolution                     1
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# primary_camera_resolution            1
# battery_type                         0
# ram_memory                           0
# internal_memory                      0
# brand_rank                           0
# no_of_cores                          0
# micro_sd_slot                        0
# screen_pixel_density                 0
# water_proof_rate                     0
# phone_width                          0
# expandable_memory                    0
# version                              0
# usb_type                             0
# battery_capacity                     0
# processor_rank                       0
# is_liked                             0
# dtype: int64

# %%
null_columns=ds.columns[ds.isnull().any()]
print(ds[ds.isnull().any(axis=1)][null_columns].head())
# Out:
#     weight  stand_by_time  no_of_reviews_in_gsmarena_in_week  phone_height  \
# 10   169.0            NaN                                5.0         152.0
# 62   170.0            NaN                              301.0         151.7
# 77   157.0          620.0                                NaN         143.2
# 83   142.6          504.0                               69.0         145.0
# 85   176.0          200.0                              226.0           NaN
#
#     talk_time  video_resolution  primary_camera_resolution
# 10       14.0             720.0                        8.0
# 62       23.0            1080.0                       13.0
# 77       23.0            1080.0                       20.0
# 83       12.0               NaN                       21.2
# 85       20.0             216.0                       16.0

# %%
ds=ds.apply(lambda x:x.fillna(x.mean()))
ds.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               0
# stand_by_time                        0
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    0
# os                                   0
# phone_height                         0
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            0
# video_resolution                     0
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# primary_camera_resolution            0
# battery_type                         0
# ram_memory                           0
# internal_memory                      0
# brand_rank                           0
# no_of_cores                          0
# micro_sd_slot                        0
# screen_pixel_density                 0
# water_proof_rate                     0
# phone_width                          0
# expandable_memory                    0
# version                              0
# usb_type                             0
# battery_capacity                     0
# processor_rank                       0
# is_liked                             0
# dtype: int64

# %%
null_columns=ds.columns[ds.isnull().any()]
print(null_columns)
print(ds[ds.isnull().any(axis=1)][null_columns].head())
# Out:
# Index([], dtype='object')
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
import matplotlib.pyplot as mtp
#import plotly.express as px
ds=pd.read_csv("mobile_cleaned-1549119762886_-452616671.csv")

# %%
col=[x for x in ds.columns]
print(col)
for i in col:
    g1=ds.price
    mtp.plot(ds[i],g1)
# Out:
# ['sim_type', 'aperture', 'gpu_rank', 'weight', 'stand_by_time', 'processor_frequency', 'thickness', 'flash_type', 'front_camera_resolution', 'auto_focus', 'screen_size', 'frames_per_second', 'FM', 'no_of_reviews_in_gsmarena_in_week', 'os', 'phone_height', 'screen_protection', 'sim_size', 'price', 'talk_time', 'video_resolution', 'display_resolution', 'removable_battery', 'display_type', 'primary_camera_resolution', 'battery_type', 'ram_memory', 'internal_memory', 'brand_rank', 'no_of_cores', 'micro_sd_slot', 'screen_pixel_density', 'water_proof_rate', 'phone_width', 'expandable_memory', 'version', 'usb_type', 'battery_capacity', 'processor_rank', 'is_liked']

# %%
p=np.array([[1,0],[0,1]])
q=np.array([[1,2],[3,4]])
r=np.outer(p,q)
print(r)
# Out:
# [[1 2 3 4]
#  [0 0 0 0]
#  [0 0 0 0]
#  [1 2 3 4]]

# %%
from numpy import linalg as ll
a=np.array([[1,2],[3,4]])
print("original matrix:")
print(a)
print("conditional number of a is:")
print(ll.cond(a))
# Out:
# original matrix:
# [[1 2]
#  [3 4]]
# conditional number of a is:
# 14.933034373659265

# %%
a=np.array([[1,2,3],[4,15,6],[7,8,9]])
sum=0
for i in range(0,3):
    for j in range(3):
        if i==j:
            sum=sum+a[i][j]
print(sum)
# Out:
# 25
